# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv("./.env")

api_key = os.getenv("OPENAI_API_KEY", "OPENAI_API_KEY")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant that can answer questions and help with tasks."),
    ("user", "Please correct me if I use incorrect expressions.\nTarget Sentence:\n{sentence}"),
])
llm = ChatOpenAI(model="gpt-5-mini", api_key=api_key)

# %%
chain = prompt
print(chain.to_json())

chain = chain | llm
print(chain.to_json())

chain = chain | StrOutputParser()
print(chain.to_json())

response = chain.invoke("Hello, how are you doin?")
print(response)
# Out:
# {'lc': 1, 'type': 'constructor', 'id': ['langchain', 'prompts', 'chat', 'ChatPromptTemplate'], 'kwargs': {'input_variables': ['sentence'], 'messages': [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant that can answer questions and help with tasks.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['sentence'], input_types={}, partial_variables={}, template='Please correct me if I use incorrect expressions.\nTarget Sentence:\n{sentence}'), additional_kwargs={})]}, 'name': 'ChatPromptTemplate'}
# {'lc': 1, 'type': 'constructor', 'id': ['langchain', 'schema', 'runnable', 'RunnableSequence'], 'kwargs': {'first': ChatPromptTemplate(input_variables=['sentence'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant that can answer questions and help with tasks.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['sentence'], input_types={}, partial_variables={}, template='Please correct me if I use incorrect expressions.\nTarget Sentence:\n{sentence}'), additional_kwargs={})]), 'last': ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x1167802f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x116780d70>, root_client=<openai.OpenAI object at 0x1162f9be0>, root_async_client=<openai.AsyncOpenAI object at 0x116780ad0>, model_name='gpt-5-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))}, 'name': 'RunnableSequence'}
# {'lc': 1, 'type': 'constructor', 'id': ['langchain', 'schema', 'runnable', 'RunnableSequence'], 'kwargs': {'first': ChatPromptTemplate(input_variables=['sentence'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant that can answer questions and help with tasks.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['sentence'], input_types={}, partial_variables={}, template='Please correct me if I use incorrect expressions.\nTarget Sentence:\n{sentence}'), additional_kwargs={})]), 'middle': [ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x1167802f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x116780d70>, root_client=<openai.OpenAI object at 0x1162f9be0>, root_async_client=<openai.AsyncOpenAI object at 0x116780ad0>, model_name='gpt-5-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))], 'last': StrOutputParser()}, 'name': 'RunnableSequence'}
# Nice try — just a couple of small fixes.
#
# Correct (standard):
# Hello, how are you doing?
#
# If you want it more formal:
# Hello. How are you doing?
#
# Casual/informal alternatives:
# Hey, how's it going?
# Hi — how are you?
#
# Notes: "doin?" is informal speech; in writing use "doing" (or "doin'" with an apostrophe only in very casual/dialogue contexts). Also put a comma (or a period) after "Hello."
